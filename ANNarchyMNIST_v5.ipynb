# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from keras.datasets import mnist


print(f"Tensorflow {tf.__version__}")
# Out:
# 2025-11-03 19:52:39.101555: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-03 19:52:39.112688: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-03 19:52:40.448414: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-03 19:52:47.775197: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-03 19:52:47.783426: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Tensorflow 2.20.0

# %%
def cnn_with_three_blocks():

    inputs = tf.keras.Input(shape=(28, 28, 1))

# Block 1
    x = Conv2D(32, (3, 3), padding='same', use_bias=False)(inputs)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)

    # Block 2
    x = Conv2D(64, (3, 3), padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)

    # Block 3
    x = Conv2D(128, (3, 3), padding='same', use_bias=False)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)


    # Classifier
    x = Flatten()(x)
    x = Dense(256, use_bias=False)(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(10, activation='softmax', use_bias=False)(x)


    # Create functional model
    model= Model(inputs, outputs)
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

    # Loss function
    model.compile(
        loss='categorical_crossentropy', # loss function
        optimizer=optimizer, # learning rule
        metrics=['accuracy'] # show accuracy
    )
    print(model.summary())

    return model

# %%
# Download data
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# Normalize inputs
train_data = train_data.astype('float32') / 255.
test_data = test_data.astype('float32') / 255.

# One-hot output vectors
train_labels_onehot = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, 10)

# %%
model = cnn_with_three_blocks()

# Train model (use one-hot labels)
history = model.fit(
    train_data, train_labels_onehot,       # training data (one-hot labels)
    batch_size=128,                        # batch size
    epochs=20,                              # Maximum number of epochs
    validation_split=0.1,                  # Percentage of training data used for validation
)

# Test model: get class predictions and evaluate with one-hot labels
predictions_keras = np.argmax(model.predict(test_data, verbose=0), axis=1)
test_loss, test_accuracy = model.evaluate(test_data, test_labels_onehot, verbose=0)
print(f"Test accuracy: {test_accuracy}")
model.save("CIFAR_v2.keras")
# Out:
# 2025-11-03 19:53:09.550090: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 14, 14, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 64)     │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 7, 7, 128)      │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 436,000 (1.66 MB)
#  Trainable params: 436,000 (1.66 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 52s 122ms/step - accuracy: 0.1127 - loss: 2.2919 - val_accuracy: 0.2252 - val_loss: 2.2514
# Epoch 2/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 49s 117ms/step - accuracy: 0.3454 - loss: 1.8424 - val_accuracy: 0.8450 - val_loss: 0.6980
# Epoch 3/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.7487 - loss: 0.7604 - val_accuracy: 0.9435 - val_loss: 0.2280
# Epoch 4/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.8648 - loss: 0.4334 - val_accuracy: 0.9592 - val_loss: 0.1431
# Epoch 5/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 37s 89ms/step - accuracy: 0.8976 - loss: 0.3306 - val_accuracy: 0.9643 - val_loss: 0.1205
# Epoch 6/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 37s 89ms/step - accuracy: 0.9148 - loss: 0.2775 - val_accuracy: 0.9702 - val_loss: 0.1030
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 37s 89ms/step - accuracy: 0.9271 - loss: 0.2375 - val_accuracy: 0.9755 - val_loss: 0.0873
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 92ms/step - accuracy: 0.9335 - loss: 0.2127 - val_accuracy: 0.9757 - val_loss: 0.0792
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.9392 - loss: 0.2001 - val_accuracy: 0.9775 - val_loss: 0.0736
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.9434 - loss: 0.1837 - val_accuracy: 0.9797 - val_loss: 0.0670
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.9471 - loss: 0.1721 - val_accuracy: 0.9812 - val_loss: 0.0630
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 90ms/step - accuracy: 0.9523 - loss: 0.1585 - val_accuracy: 0.9817 - val_loss: 0.0599
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.9517 - loss: 0.1548 - val_accuracy: 0.9818 - val_loss: 0.0603
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 38s 90ms/step - accuracy: 0.9552 - loss: 0.1430 - val_accuracy: 0.9833 - val_loss: 0.0561
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 39s 93ms/step - accuracy: 0.9567 - loss: 0.1394 - val_accuracy: 0.9842 - val_loss: 0.0531
# Epoch 16/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 99ms/step - accuracy: 0.9583 - loss: 0.1337 - val_accuracy: 0.9853 - val_loss: 0.0516
# Epoch 17/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 41s 96ms/step - accuracy: 0.9604 - loss: 0.1268 - val_accuracy: 0.9860 - val_loss: 0.0499
# Epoch 18/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 39s 93ms/step - accuracy: 0.9619 - loss: 0.1228 - val_accuracy: 0.9862 - val_loss: 0.0490
# Epoch 19/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.9635 - loss: 0.1187 - val_accuracy: 0.9862 - val_loss: 0.0469
# Epoch 20/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.9645 - loss: 0.1154 - val_accuracy: 0.9852 - val_loss: 0.0483
# Test accuracy: 0.9858999848365784

# %%
import ANNarchy
from ANNarchy.extensions.ann_to_snn_conversion import ANNtoSNNConverter
ANNarchy.clear()
snn_converter = ANNtoSNNConverter(
    input_encoding='IB', 
    hidden_neuron='IaF',
    read_out='spike_count',
)
# Out:
# ANNarchy 4.8 (4.8.2.5) on linux (posix).

# %%
net = snn_converter.load_keras_model("CIFAR_v2.keras", show_info=True)
# Out:
# WARNING: Dense representation is an experimental feature for spiking models, we greatly appreciate bug reports.
# * Input layer: input_layer, (28, 28, 1)
# * InputLayer skipped.
# * Conv2D layer: conv2d, (28, 28, 32)
# * Activation skipped.
# * Conv2D layer: conv2d_1, (28, 28, 32)
# * Activation skipped.
# * MaxPooling2D layer: max_pooling2d, (14, 14, 32)
# * Dropout skipped.
# * Conv2D layer: conv2d_2, (14, 14, 64)
# * Activation skipped.
# * Conv2D layer: conv2d_3, (14, 14, 64)
# * Activation skipped.
# * MaxPooling2D layer: max_pooling2d_1, (7, 7, 64)
# * Dropout skipped.
# * Conv2D layer: conv2d_4, (7, 7, 128)
# * Activation skipped.
# * MaxPooling2D layer: max_pooling2d_2, (3, 3, 128)
# * Dropout skipped.
# * Flatten skipped.
# * Dense layer: dense, 256
#     weights: (256, 1152)
#     mean -0.0005399816436693072, std 0.03781595453619957
#     min -0.10682898014783859, max 0.11740609258413315
# * Activation skipped.
# * Dropout skipped.
# * Dense layer: dense_1, 10
#     weights: (10, 256)
#     mean -0.0027136304415762424, std 0.0942515954375267
#     min -0.2217751294374466, max 0.21097716689109802

# %%
predictions_snn = snn_converter.predict(test_data[:300], duration_per_sample=200)
# Out:
# 100%|██████████| 300/300 [21:30<00:00,  4.30s/it]

# %%
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

print(classification_report(test_labels[:300], predictions_snn))
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       1.00      1.00      1.00        41
#            2       1.00      0.97      0.98        32
#            3       1.00      0.96      0.98        24
#            4       0.97      0.92      0.94        37
#            5       1.00      1.00      1.00        29
#            6       0.96      0.92      0.94        24
#            7       0.97      1.00      0.99        34
#            8       0.91      1.00      0.95        21
#            9       0.94      0.97      0.96        34
#
#     accuracy                           0.97       300
#    macro avg       0.97      0.97      0.97       300
# weighted avg       0.97      0.97      0.97       300
#
# Test accuracy of the SNN: 0.9733333333333334

# %%
model = tf.keras.models.load_model('CIFAR_v2.keras')
loss, accuracy = model.evaluate(test_data, test_labels_onehot, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9859 - loss: 0.0434

# %%
print(f"Test accuracy of the ANN: {accuracy:.4f}")
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
# Test accuracy of the ANN: 0.9859
# Test accuracy of the SNN: 0.9733333333333334
