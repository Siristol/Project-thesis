# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.layers import Activation
from keras.layers import Conv2D, MaxPooling2D, Input
from keras.layers import BatchNormalization
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Model, Sequential

# %%
# Download data
(train_data, train_labels), (test_data, test_labels) = cifar10.load_data()

# Normalize inputs
train_data = train_data.astype('float32') / 255.
test_data = test_data.astype('float32') / 255.

# One-hot output vectors
train_labels_onehot = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, 10)

# %%
def define_model():
    inputs = Input(shape=(32, 32, 3))

    x = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.2)(x)

    x = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)

    x = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)

    x = Flatten()(x)
    x = Dense(128, activation='relu', kernel_initializer='he_uniform')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)

    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    return model
model = define_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 552,874 (2.11 MB)
#  Trainable params: 551,722 (2.10 MB)
#  Non-trainable params: 1,152 (4.50 KB)

# %%
# Train model (use one-hot labels)
history = model.fit(
    train_data, train_labels_onehot,       # training data (one-hot labels)
    batch_size=64,                        # batch size
    epochs=100,                            # Maximum number of epochs
    validation_split=0.1,                  # Percentage of training data used for validation
)

# Test model: get class predictions and evaluate with one-hot labels
predictions_keras = np.argmax(model.predict(test_data, verbose=0), axis=1)
test_loss, test_accuracy = model.evaluate(test_data, test_labels_onehot, verbose=0)
print(f"Test accuracy: {test_accuracy}")
model.save("CIFAR_v12_vgg.keras")
# Out:
# Epoch 1/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 86s 118ms/step - accuracy: 0.3063 - loss: 2.1098 - val_accuracy: 0.4376 - val_loss: 1.5224
# Epoch 2/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 83s 118ms/step - accuracy: 0.4246 - loss: 1.5781 - val_accuracy: 0.4488 - val_loss: 1.5151
# Epoch 3/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 81s 115ms/step - accuracy: 0.4790 - loss: 1.4263 - val_accuracy: 0.4676 - val_loss: 1.4619
# Epoch 4/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 83s 118ms/step - accuracy: 0.5150 - loss: 1.3403 - val_accuracy: 0.5550 - val_loss: 1.2317
# Epoch 5/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 85s 121ms/step - accuracy: 0.5456 - loss: 1.2579 - val_accuracy: 0.5000 - val_loss: 1.3759
# Epoch 6/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 95s 135ms/step - accuracy: 0.5684 - loss: 1.1979 - val_accuracy: 0.5902 - val_loss: 1.1367
# Epoch 7/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.5877 - loss: 1.1482 - val_accuracy: 0.6102 - val_loss: 1.0817
# Epoch 8/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.6012 - loss: 1.1032 - val_accuracy: 0.6062 - val_loss: 1.0968
# Epoch 9/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 140ms/step - accuracy: 0.6154 - loss: 1.0722 - val_accuracy: 0.6548 - val_loss: 0.9807
# Epoch 10/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.6301 - loss: 1.0386 - val_accuracy: 0.6598 - val_loss: 0.9663
# Epoch 11/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.6397 - loss: 1.0125 - val_accuracy: 0.6746 - val_loss: 0.9151
# Epoch 12/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.6500 - loss: 0.9842 - val_accuracy: 0.6816 - val_loss: 0.8804
# Epoch 13/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 106s 151ms/step - accuracy: 0.6588 - loss: 0.9639 - val_accuracy: 0.6470 - val_loss: 0.9962
# Epoch 14/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 141ms/step - accuracy: 0.6693 - loss: 0.9375 - val_accuracy: 0.6850 - val_loss: 0.8743
# Epoch 15/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 98s 139ms/step - accuracy: 0.6732 - loss: 0.9187 - val_accuracy: 0.7022 - val_loss: 0.8394
# Epoch 16/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.6835 - loss: 0.8960 - val_accuracy: 0.6996 - val_loss: 0.8403
# Epoch 17/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.6902 - loss: 0.8777 - val_accuracy: 0.7084 - val_loss: 0.8235
# Epoch 18/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.6972 - loss: 0.8595 - val_accuracy: 0.7166 - val_loss: 0.7989
# Epoch 19/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 140ms/step - accuracy: 0.7015 - loss: 0.8449 - val_accuracy: 0.7240 - val_loss: 0.7912
# Epoch 20/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7091 - loss: 0.8250 - val_accuracy: 0.7256 - val_loss: 0.7798
# Epoch 21/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.7116 - loss: 0.8168 - val_accuracy: 0.7308 - val_loss: 0.7619
# Epoch 22/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 143ms/step - accuracy: 0.7155 - loss: 0.8087 - val_accuracy: 0.7506 - val_loss: 0.7063
# Epoch 23/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 140ms/step - accuracy: 0.7215 - loss: 0.7935 - val_accuracy: 0.7550 - val_loss: 0.7019
# Epoch 24/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 110s 156ms/step - accuracy: 0.7236 - loss: 0.7810 - val_accuracy: 0.7632 - val_loss: 0.6801
# Epoch 25/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 117s 166ms/step - accuracy: 0.7306 - loss: 0.7678 - val_accuracy: 0.7514 - val_loss: 0.7168
# Epoch 26/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.7338 - loss: 0.7619 - val_accuracy: 0.7646 - val_loss: 0.6779
# Epoch 27/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7379 - loss: 0.7514 - val_accuracy: 0.7598 - val_loss: 0.6853
# Epoch 28/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 144ms/step - accuracy: 0.7394 - loss: 0.7433 - val_accuracy: 0.7452 - val_loss: 0.7215
# Epoch 29/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 143ms/step - accuracy: 0.7424 - loss: 0.7332 - val_accuracy: 0.7748 - val_loss: 0.6551
# Epoch 30/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 145ms/step - accuracy: 0.7467 - loss: 0.7225 - val_accuracy: 0.7730 - val_loss: 0.6544
# Epoch 31/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.7498 - loss: 0.7148 - val_accuracy: 0.7680 - val_loss: 0.6580
# Epoch 32/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 143ms/step - accuracy: 0.7522 - loss: 0.7068 - val_accuracy: 0.7704 - val_loss: 0.6505
# Epoch 33/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 105s 149ms/step - accuracy: 0.7557 - loss: 0.6992 - val_accuracy: 0.7836 - val_loss: 0.6114
# Epoch 34/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.7582 - loss: 0.6895 - val_accuracy: 0.7730 - val_loss: 0.6403
# Epoch 35/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7614 - loss: 0.6788 - val_accuracy: 0.7702 - val_loss: 0.6669
# Epoch 36/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7648 - loss: 0.6737 - val_accuracy: 0.7668 - val_loss: 0.6666
# Epoch 37/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.7677 - loss: 0.6620 - val_accuracy: 0.7790 - val_loss: 0.6298
# Epoch 38/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7673 - loss: 0.6600 - val_accuracy: 0.7550 - val_loss: 0.7053
# Epoch 39/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7713 - loss: 0.6525 - val_accuracy: 0.7886 - val_loss: 0.6049
# Epoch 40/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.7764 - loss: 0.6458 - val_accuracy: 0.7886 - val_loss: 0.6189
# Epoch 41/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.7783 - loss: 0.6366 - val_accuracy: 0.7768 - val_loss: 0.6428
# Epoch 42/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.7824 - loss: 0.6284 - val_accuracy: 0.7844 - val_loss: 0.6136
# Epoch 43/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 145ms/step - accuracy: 0.7824 - loss: 0.6240 - val_accuracy: 0.7916 - val_loss: 0.5915
# Epoch 44/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.7851 - loss: 0.6156 - val_accuracy: 0.8014 - val_loss: 0.5797
# Epoch 45/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.7850 - loss: 0.6132 - val_accuracy: 0.7812 - val_loss: 0.6327
# Epoch 46/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.7885 - loss: 0.6038 - val_accuracy: 0.8014 - val_loss: 0.5828
# Epoch 47/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 140ms/step - accuracy: 0.7896 - loss: 0.6021 - val_accuracy: 0.7974 - val_loss: 0.5807
# Epoch 48/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.7938 - loss: 0.5875 - val_accuracy: 0.7896 - val_loss: 0.6146
# Epoch 49/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 103s 146ms/step - accuracy: 0.7942 - loss: 0.5868 - val_accuracy: 0.8024 - val_loss: 0.5702
# Epoch 50/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.7953 - loss: 0.5864 - val_accuracy: 0.7888 - val_loss: 0.6083
# Epoch 51/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.7964 - loss: 0.5806 - val_accuracy: 0.7902 - val_loss: 0.6291
# Epoch 52/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8008 - loss: 0.5700 - val_accuracy: 0.8088 - val_loss: 0.5538
# Epoch 53/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 141ms/step - accuracy: 0.8039 - loss: 0.5620 - val_accuracy: 0.8136 - val_loss: 0.5403
# Epoch 54/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 98s 139ms/step - accuracy: 0.8052 - loss: 0.5616 - val_accuracy: 0.8150 - val_loss: 0.5545
# Epoch 55/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 144ms/step - accuracy: 0.8061 - loss: 0.5562 - val_accuracy: 0.8056 - val_loss: 0.5571
# Epoch 56/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8084 - loss: 0.5506 - val_accuracy: 0.8094 - val_loss: 0.5447
# Epoch 57/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8095 - loss: 0.5446 - val_accuracy: 0.8086 - val_loss: 0.5700
# Epoch 58/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.8106 - loss: 0.5386 - val_accuracy: 0.7772 - val_loss: 0.6522
# Epoch 59/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 143ms/step - accuracy: 0.8107 - loss: 0.5416 - val_accuracy: 0.8190 - val_loss: 0.5346
# Epoch 60/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8146 - loss: 0.5312 - val_accuracy: 0.8144 - val_loss: 0.5460
# Epoch 61/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8168 - loss: 0.5290 - val_accuracy: 0.8072 - val_loss: 0.5625
# Epoch 62/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 144ms/step - accuracy: 0.8183 - loss: 0.5180 - val_accuracy: 0.8150 - val_loss: 0.5394
# Epoch 63/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 143ms/step - accuracy: 0.8219 - loss: 0.5110 - val_accuracy: 0.8096 - val_loss: 0.5556
# Epoch 64/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8196 - loss: 0.5162 - val_accuracy: 0.8224 - val_loss: 0.5187
# Epoch 65/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 98s 140ms/step - accuracy: 0.8235 - loss: 0.5025 - val_accuracy: 0.8076 - val_loss: 0.5569
# Epoch 66/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8231 - loss: 0.5014 - val_accuracy: 0.8112 - val_loss: 0.5611
# Epoch 67/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 104s 147ms/step - accuracy: 0.8266 - loss: 0.4983 - val_accuracy: 0.8188 - val_loss: 0.5308
# Epoch 68/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 141ms/step - accuracy: 0.8278 - loss: 0.4934 - val_accuracy: 0.8162 - val_loss: 0.5407
# Epoch 69/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8315 - loss: 0.4881 - val_accuracy: 0.8172 - val_loss: 0.5405
# Epoch 70/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8278 - loss: 0.4845 - val_accuracy: 0.8196 - val_loss: 0.5375
# Epoch 71/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 99s 141ms/step - accuracy: 0.8317 - loss: 0.4818 - val_accuracy: 0.8220 - val_loss: 0.5468
# Epoch 72/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8343 - loss: 0.4726 - val_accuracy: 0.8284 - val_loss: 0.5093
# Epoch 73/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 144ms/step - accuracy: 0.8362 - loss: 0.4709 - val_accuracy: 0.8270 - val_loss: 0.5153
# Epoch 74/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8390 - loss: 0.4664 - val_accuracy: 0.8298 - val_loss: 0.4967
# Epoch 75/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8373 - loss: 0.4639 - val_accuracy: 0.8310 - val_loss: 0.5006
# Epoch 76/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8395 - loss: 0.4600 - val_accuracy: 0.8202 - val_loss: 0.5385
# Epoch 77/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8423 - loss: 0.4528 - val_accuracy: 0.8388 - val_loss: 0.4832
# Epoch 78/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8419 - loss: 0.4549 - val_accuracy: 0.8334 - val_loss: 0.4969
# Epoch 79/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8416 - loss: 0.4525 - val_accuracy: 0.8146 - val_loss: 0.5611
# Epoch 80/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8453 - loss: 0.4455 - val_accuracy: 0.8328 - val_loss: 0.4972
# Epoch 81/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 100s 142ms/step - accuracy: 0.8445 - loss: 0.4418 - val_accuracy: 0.8314 - val_loss: 0.5180
# Epoch 82/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8461 - loss: 0.4363 - val_accuracy: 0.8338 - val_loss: 0.4971
# Epoch 83/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8460 - loss: 0.4350 - val_accuracy: 0.8256 - val_loss: 0.5122
# Epoch 84/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 144ms/step - accuracy: 0.8505 - loss: 0.4307 - val_accuracy: 0.8304 - val_loss: 0.5076
# Epoch 85/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 103s 146ms/step - accuracy: 0.8490 - loss: 0.4302 - val_accuracy: 0.8226 - val_loss: 0.5419
# Epoch 86/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 103s 146ms/step - accuracy: 0.8523 - loss: 0.4209 - val_accuracy: 0.8302 - val_loss: 0.5101
# Epoch 87/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8524 - loss: 0.4205 - val_accuracy: 0.8414 - val_loss: 0.4708
# Epoch 88/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8538 - loss: 0.4167 - val_accuracy: 0.8296 - val_loss: 0.5142
# Epoch 89/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 103s 147ms/step - accuracy: 0.8524 - loss: 0.4220 - val_accuracy: 0.8284 - val_loss: 0.5010
# Epoch 90/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8544 - loss: 0.4116 - val_accuracy: 0.8308 - val_loss: 0.5094
# Epoch 91/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 143ms/step - accuracy: 0.8581 - loss: 0.4065 - val_accuracy: 0.8370 - val_loss: 0.4896
# Epoch 92/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 103s 146ms/step - accuracy: 0.8568 - loss: 0.4081 - val_accuracy: 0.8324 - val_loss: 0.5246
# Epoch 93/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 145ms/step - accuracy: 0.8608 - loss: 0.3952 - val_accuracy: 0.8354 - val_loss: 0.5055
# Epoch 94/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8598 - loss: 0.4005 - val_accuracy: 0.8358 - val_loss: 0.4923
# Epoch 95/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8620 - loss: 0.3936 - val_accuracy: 0.8314 - val_loss: 0.5189
# Epoch 96/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8627 - loss: 0.3951 - val_accuracy: 0.8376 - val_loss: 0.4807
# Epoch 97/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8628 - loss: 0.3936 - val_accuracy: 0.8390 - val_loss: 0.4894
# Epoch 98/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 101s 144ms/step - accuracy: 0.8653 - loss: 0.3884 - val_accuracy: 0.8416 - val_loss: 0.4744
# Epoch 99/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 145ms/step - accuracy: 0.8662 - loss: 0.3840 - val_accuracy: 0.8244 - val_loss: 0.5429
# Epoch 100/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 102s 144ms/step - accuracy: 0.8676 - loss: 0.3795 - val_accuracy: 0.8348 - val_loss: 0.5052
# Test accuracy: 0.8337000012397766

# %%
import ANNarchy
from ANNarchy.extensions.ann_to_snn_conversion import ANNtoSNNConverter
ANNarchy.clear()
snn_converter = ANNtoSNNConverter(
    input_encoding='IB', 
    hidden_neuron='IaF',
    read_out='spike_count',
)
# Out:
# ANNarchy 4.8 (4.8.2.5) on linux (posix).

# %%
net = snn_converter.load_keras_model("CIFAR_v12_vgg.keras", show_info=True)
# Out:
# WARNING: Dense representation is an experimental feature for spiking models, we greatly appreciate bug reports.
# * Input layer: input_layer_1, (32, 32, 3)
# * InputLayer skipped.
# * Conv2D layer: conv2d_6, (32, 32, 32)
# * BatchNormalization skipped.
# * Conv2D layer: conv2d_7, (32, 32, 32)
# * BatchNormalization skipped.
# * MaxPooling2D layer: max_pooling2d_3, (16, 16, 32)
# * Dropout skipped.
# * Conv2D layer: conv2d_8, (16, 16, 64)
# * BatchNormalization skipped.
# * Conv2D layer: conv2d_9, (16, 16, 64)
# * BatchNormalization skipped.
# * MaxPooling2D layer: max_pooling2d_4, (8, 8, 64)
# * Dropout skipped.
# * Conv2D layer: conv2d_10, (8, 8, 128)
# * BatchNormalization skipped.
# * Conv2D layer: conv2d_11, (8, 8, 128)
# * BatchNormalization skipped.
# * MaxPooling2D layer: max_pooling2d_5, (4, 4, 128)
# * Dropout skipped.
# * Flatten skipped.
# * Dense layer: dense_2, 128
#     weights: (128, 2048)
#     mean 0.001673636375926435, std 0.03229540213942528
#     min -0.1370910257101059, max 0.12372682988643646
# * BatchNormalization skipped.
# * Dropout skipped.
# * Dense layer: dense_3, 10
#     weights: (10, 128)
#     mean 0.0021811097394675016, std 0.11199067533016205
#     min -0.24159088730812073, max 0.26820704340934753

# %%
predictions_snn = snn_converter.predict(test_data[:300], duration_per_sample=200)
# Out:
# 100%|██████████| 300/300 [53:45<00:00, 10.75s/it]

# %%
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

print(classification_report(test_labels[:300], predictions_snn))
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        36
#            1       0.09      0.33      0.14        24
#            2       0.00      0.00      0.00        27
#            3       0.00      0.00      0.00        29
#            4       0.00      0.00      0.00        23
#            5       0.00      0.00      0.00        28
#            6       0.00      0.00      0.00        34
#            7       0.00      0.00      0.00        27
#            8       0.05      0.05      0.05        37
#            9       0.16      0.77      0.26        35
#
#     accuracy                           0.12       300
#    macro avg       0.03      0.12      0.05       300
# weighted avg       0.03      0.12      0.05       300
#
# Test accuracy of the SNN: 0.12333333333333334
# /home/sist/projects/test_ann_to_snn/venv_annarchy/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/sist/projects/test_ann_to_snn/venv_annarchy/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/sist/projects/test_ann_to_snn/venv_annarchy/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
model = tf.keras.models.load_model('CIFAR_v12_vgg.keras')
loss, accuracy = model.evaluate(test_data, test_labels_onehot, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8337 - loss: 0.5216

# %%
print(f"Test accuracy of the ANN: {accuracy:.4f}")
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
# Test accuracy of the ANN: 0.8337
# Test accuracy of the SNN: 0.12333333333333334
