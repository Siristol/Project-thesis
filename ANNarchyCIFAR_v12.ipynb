# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.layers import Activation
from keras.layers import Conv2D, MaxPooling2D, Input
from keras.layers import BatchNormalization
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Model, Sequential
# Out:
# 2025-11-13 09:34:28.413121: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-13 09:34:28.446314: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-13 09:34:29.441182: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-13 09:34:32.467556: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-13 09:34:32.473268: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Download data
(train_data, train_labels), (test_data, test_labels) = cifar10.load_data()

# Normalize inputs
train_data = train_data.astype('float32') / 255.
test_data = test_data.astype('float32') / 255.

# One-hot output vectors
train_labels_onehot = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, 10)

# %%
def define_functional_model():
    inputs = Input(shape=(32, 32, 3), name="input_layer")
    x = Conv2D(32, (3, 3), use_bias=False, activation='relu', padding='same', name='block1_conv1')(inputs)
    x = Conv2D(32, (3, 3), use_bias=False, activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), name='block1_pool')(x)
    x = Dropout(0.2, name='block1_dropout')(x)
    x = Conv2D(64, (3, 3), use_bias=False, activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(64, (3, 3), use_bias=False, activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), name='block2_pool')(x)
    x = Dropout(0.2, name='block2_dropout')(x)
    x = Conv2D(128, (3, 3), use_bias=False, activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(128, (3, 3), use_bias=False, activation='relu', padding='same', name='block3_conv2')(x)
    x = MaxPooling2D((2, 2), name='block3_pool')(x)
    x = Dropout(0.2, name='block3_dropout')(x)
    x = Flatten(name='flatten')(x)
    x = Dense(128, use_bias=False, activation='relu', kernel_initializer='he_uniform', name='fc1')(x)
    x = Dropout(0.2, name='fc1_dropout')(x)
    outputs = Dense(10, use_bias=False, activation='softmax', name='predictions')(x)
    
    model = Model(inputs=inputs, outputs=outputs, name="cifar10_functional_cnn")
    
    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

model = define_functional_model()
model.summary()
# Out:
# Model: "cifar10_functional_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 32, 32, 32)     │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 32, 32, 32)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_dropout (Dropout)        │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 16, 16, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 16, 16, 64)     │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_dropout (Dropout)        │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 8, 8, 128)      │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 8, 8, 128)      │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_dropout (Dropout)        │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 128)            │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1_dropout (Dropout)           │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 10)             │         1,280 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 549,984 (2.10 MB)
#  Trainable params: 549,984 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train model (use one-hot labels)
history = model.fit(
    train_data, train_labels_onehot,       # training data (one-hot labels)
    batch_size=64,                        # batch size
    epochs=100,                            # Maximum number of epochs
    validation_split=0.1,                  # Percentage of training data used for validation
)

# Test model: get class predictions and evaluate with one-hot labels
predictions_keras = np.argmax(model.predict(test_data, verbose=0), axis=1)
test_loss, test_accuracy = model.evaluate(test_data, test_labels_onehot, verbose=0)
print(f"Test accuracy: {test_accuracy}")
model.save("CIFAR_v12_vgg.keras")
# Out:
# Epoch 1/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 50s 69ms/step - accuracy: 0.1165 - loss: 2.2893 - val_accuracy: 0.1820 - val_loss: 2.2364
# Epoch 2/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 53s 75ms/step - accuracy: 0.2266 - loss: 2.0861 - val_accuracy: 0.2890 - val_loss: 1.9501
# Epoch 3/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 53s 76ms/step - accuracy: 0.2974 - loss: 1.9275 - val_accuracy: 0.3486 - val_loss: 1.8261
# Epoch 4/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 85ms/step - accuracy: 0.3474 - loss: 1.8036 - val_accuracy: 0.3908 - val_loss: 1.7024
# Epoch 5/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.3850 - loss: 1.6960 - val_accuracy: 0.4244 - val_loss: 1.5818
# Epoch 6/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.4138 - loss: 1.6157 - val_accuracy: 0.4382 - val_loss: 1.5293
# Epoch 7/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.4379 - loss: 1.5521 - val_accuracy: 0.4814 - val_loss: 1.4487
# Epoch 8/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.4594 - loss: 1.4924 - val_accuracy: 0.4962 - val_loss: 1.3902
# Epoch 9/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 86ms/step - accuracy: 0.4792 - loss: 1.4392 - val_accuracy: 0.5282 - val_loss: 1.3223
# Epoch 10/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.5022 - loss: 1.3840 - val_accuracy: 0.5396 - val_loss: 1.2838
# Epoch 11/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 68s 97ms/step - accuracy: 0.5235 - loss: 1.3277 - val_accuracy: 0.5580 - val_loss: 1.2418
# Epoch 12/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 73s 104ms/step - accuracy: 0.5419 - loss: 1.2810 - val_accuracy: 0.5746 - val_loss: 1.1763
# Epoch 13/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 89ms/step - accuracy: 0.5601 - loss: 1.2367 - val_accuracy: 0.6098 - val_loss: 1.1138
# Epoch 14/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.5748 - loss: 1.1917 - val_accuracy: 0.6170 - val_loss: 1.0907
# Epoch 15/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 89ms/step - accuracy: 0.5918 - loss: 1.1481 - val_accuracy: 0.6262 - val_loss: 1.0534
# Epoch 16/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.6071 - loss: 1.1048 - val_accuracy: 0.6358 - val_loss: 1.0312
# Epoch 17/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.6171 - loss: 1.0751 - val_accuracy: 0.6536 - val_loss: 1.0055
# Epoch 18/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.6320 - loss: 1.0428 - val_accuracy: 0.6554 - val_loss: 0.9812
# Epoch 19/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.6403 - loss: 1.0142 - val_accuracy: 0.6576 - val_loss: 0.9878
# Epoch 20/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 61s 87ms/step - accuracy: 0.6517 - loss: 0.9878 - val_accuracy: 0.6768 - val_loss: 0.9299
# Epoch 21/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.6582 - loss: 0.9683 - val_accuracy: 0.6940 - val_loss: 0.8914
# Epoch 22/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.6675 - loss: 0.9404 - val_accuracy: 0.6964 - val_loss: 0.8595
# Epoch 23/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 62s 88ms/step - accuracy: 0.6752 - loss: 0.9222 - val_accuracy: 0.7036 - val_loss: 0.8595
# Epoch 24/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 68s 96ms/step - accuracy: 0.6825 - loss: 0.8996 - val_accuracy: 0.7046 - val_loss: 0.8578
# Epoch 25/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 90ms/step - accuracy: 0.6912 - loss: 0.8809 - val_accuracy: 0.7024 - val_loss: 0.8492
# Epoch 26/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.6983 - loss: 0.8554 - val_accuracy: 0.7198 - val_loss: 0.8128
# Epoch 27/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 90ms/step - accuracy: 0.7011 - loss: 0.8462 - val_accuracy: 0.7218 - val_loss: 0.8110
# Epoch 28/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 90ms/step - accuracy: 0.7086 - loss: 0.8256 - val_accuracy: 0.7162 - val_loss: 0.8418
# Epoch 29/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.7178 - loss: 0.8039 - val_accuracy: 0.7358 - val_loss: 0.7718
# Epoch 30/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.7224 - loss: 0.7934 - val_accuracy: 0.7382 - val_loss: 0.7682
# Epoch 31/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 68s 96ms/step - accuracy: 0.7256 - loss: 0.7767 - val_accuracy: 0.7440 - val_loss: 0.7399
# Epoch 32/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7309 - loss: 0.7649 - val_accuracy: 0.7464 - val_loss: 0.7577
# Epoch 33/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 92ms/step - accuracy: 0.7363 - loss: 0.7467 - val_accuracy: 0.7462 - val_loss: 0.7410
# Epoch 34/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 62s 88ms/step - accuracy: 0.7394 - loss: 0.7347 - val_accuracy: 0.7510 - val_loss: 0.7196
# Epoch 35/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.7464 - loss: 0.7218 - val_accuracy: 0.7520 - val_loss: 0.7207
# Epoch 36/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7519 - loss: 0.7045 - val_accuracy: 0.7522 - val_loss: 0.7248
# Epoch 37/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7575 - loss: 0.6948 - val_accuracy: 0.7574 - val_loss: 0.6962
# Epoch 38/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 95ms/step - accuracy: 0.7598 - loss: 0.6790 - val_accuracy: 0.7584 - val_loss: 0.6940
# Epoch 39/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7685 - loss: 0.6585 - val_accuracy: 0.7674 - val_loss: 0.6894
# Epoch 40/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7713 - loss: 0.6501 - val_accuracy: 0.7638 - val_loss: 0.6872
# Epoch 41/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7758 - loss: 0.6409 - val_accuracy: 0.7692 - val_loss: 0.6789
# Epoch 42/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.7784 - loss: 0.6265 - val_accuracy: 0.7708 - val_loss: 0.6714
# Epoch 43/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 78s 88ms/step - accuracy: 0.7839 - loss: 0.6102 - val_accuracy: 0.7768 - val_loss: 0.6635
# Epoch 44/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7882 - loss: 0.5966 - val_accuracy: 0.7830 - val_loss: 0.6444
# Epoch 45/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.7907 - loss: 0.5909 - val_accuracy: 0.7736 - val_loss: 0.6640
# Epoch 46/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.7931 - loss: 0.5799 - val_accuracy: 0.7794 - val_loss: 0.6453
# Epoch 47/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8009 - loss: 0.5675 - val_accuracy: 0.7762 - val_loss: 0.6450
# Epoch 48/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8006 - loss: 0.5613 - val_accuracy: 0.7858 - val_loss: 0.6347
# Epoch 49/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8062 - loss: 0.5527 - val_accuracy: 0.7886 - val_loss: 0.6218
# Epoch 50/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 93ms/step - accuracy: 0.8099 - loss: 0.5368 - val_accuracy: 0.7732 - val_loss: 0.6641
# Epoch 51/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8134 - loss: 0.5235 - val_accuracy: 0.7880 - val_loss: 0.6348
# Epoch 52/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.8155 - loss: 0.5196 - val_accuracy: 0.7880 - val_loss: 0.6383
# Epoch 53/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8191 - loss: 0.5099 - val_accuracy: 0.7934 - val_loss: 0.6173
# Epoch 54/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.8222 - loss: 0.5005 - val_accuracy: 0.7916 - val_loss: 0.6283
# Epoch 55/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.8257 - loss: 0.4945 - val_accuracy: 0.7872 - val_loss: 0.6515
# Epoch 56/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 96ms/step - accuracy: 0.8240 - loss: 0.4840 - val_accuracy: 0.7922 - val_loss: 0.6237
# Epoch 57/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 93ms/step - accuracy: 0.8312 - loss: 0.4736 - val_accuracy: 0.7856 - val_loss: 0.6424
# Epoch 58/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 68s 96ms/step - accuracy: 0.8337 - loss: 0.4677 - val_accuracy: 0.7926 - val_loss: 0.6075
# Epoch 59/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8385 - loss: 0.4552 - val_accuracy: 0.7910 - val_loss: 0.6137
# Epoch 60/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.8375 - loss: 0.4557 - val_accuracy: 0.7964 - val_loss: 0.6167
# Epoch 61/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8446 - loss: 0.4357 - val_accuracy: 0.7950 - val_loss: 0.6361
# Epoch 62/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 93ms/step - accuracy: 0.8450 - loss: 0.4325 - val_accuracy: 0.7980 - val_loss: 0.6095
# Epoch 63/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8465 - loss: 0.4259 - val_accuracy: 0.7976 - val_loss: 0.6289
# Epoch 64/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8492 - loss: 0.4220 - val_accuracy: 0.8002 - val_loss: 0.5970
# Epoch 65/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8533 - loss: 0.4085 - val_accuracy: 0.7974 - val_loss: 0.6245
# Epoch 66/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.8544 - loss: 0.4041 - val_accuracy: 0.7982 - val_loss: 0.6080
# Epoch 67/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8592 - loss: 0.3969 - val_accuracy: 0.7970 - val_loss: 0.6193
# Epoch 68/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8568 - loss: 0.3921 - val_accuracy: 0.7992 - val_loss: 0.6111
# Epoch 69/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8629 - loss: 0.3837 - val_accuracy: 0.8032 - val_loss: 0.6184
# Epoch 70/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8661 - loss: 0.3724 - val_accuracy: 0.8022 - val_loss: 0.6221
# Epoch 71/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 93ms/step - accuracy: 0.8670 - loss: 0.3698 - val_accuracy: 0.8000 - val_loss: 0.6315
# Epoch 72/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.8677 - loss: 0.3647 - val_accuracy: 0.8008 - val_loss: 0.6390
# Epoch 73/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 93ms/step - accuracy: 0.8713 - loss: 0.3544 - val_accuracy: 0.8008 - val_loss: 0.6147
# Epoch 74/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8728 - loss: 0.3539 - val_accuracy: 0.7994 - val_loss: 0.6391
# Epoch 75/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 68s 97ms/step - accuracy: 0.8766 - loss: 0.3443 - val_accuracy: 0.8028 - val_loss: 0.6114
# Epoch 76/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8773 - loss: 0.3418 - val_accuracy: 0.8036 - val_loss: 0.6076
# Epoch 77/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.8787 - loss: 0.3367 - val_accuracy: 0.8022 - val_loss: 0.6200
# Epoch 78/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8818 - loss: 0.3285 - val_accuracy: 0.8040 - val_loss: 0.6329
# Epoch 79/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8858 - loss: 0.3193 - val_accuracy: 0.8094 - val_loss: 0.6287
# Epoch 80/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8861 - loss: 0.3181 - val_accuracy: 0.8002 - val_loss: 0.6400
# Epoch 81/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8893 - loss: 0.3111 - val_accuracy: 0.8022 - val_loss: 0.6255
# Epoch 82/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 93ms/step - accuracy: 0.8899 - loss: 0.3029 - val_accuracy: 0.8074 - val_loss: 0.6343
# Epoch 83/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.8927 - loss: 0.2984 - val_accuracy: 0.8038 - val_loss: 0.6282
# Epoch 84/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 69s 97ms/step - accuracy: 0.8902 - loss: 0.3037 - val_accuracy: 0.8076 - val_loss: 0.6247
# Epoch 85/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.8926 - loss: 0.2966 - val_accuracy: 0.8066 - val_loss: 0.6411
# Epoch 86/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 70s 99ms/step - accuracy: 0.8970 - loss: 0.2898 - val_accuracy: 0.8078 - val_loss: 0.6317
# Epoch 87/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 63s 90ms/step - accuracy: 0.8962 - loss: 0.2859 - val_accuracy: 0.8064 - val_loss: 0.6396
# Epoch 88/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 96ms/step - accuracy: 0.8970 - loss: 0.2828 - val_accuracy: 0.8020 - val_loss: 0.6433
# Epoch 89/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 95ms/step - accuracy: 0.9004 - loss: 0.2772 - val_accuracy: 0.8004 - val_loss: 0.6505
# Epoch 90/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 95ms/step - accuracy: 0.9019 - loss: 0.2734 - val_accuracy: 0.8044 - val_loss: 0.6483
# Epoch 91/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 94ms/step - accuracy: 0.9021 - loss: 0.2736 - val_accuracy: 0.8056 - val_loss: 0.6493
# Epoch 92/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.9048 - loss: 0.2645 - val_accuracy: 0.8076 - val_loss: 0.6437
# Epoch 93/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 69s 98ms/step - accuracy: 0.9051 - loss: 0.2578 - val_accuracy: 0.8036 - val_loss: 0.6406
# Epoch 94/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.9087 - loss: 0.2556 - val_accuracy: 0.8074 - val_loss: 0.6569
# Epoch 95/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.9087 - loss: 0.2503 - val_accuracy: 0.8100 - val_loss: 0.6645
# Epoch 96/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.9099 - loss: 0.2502 - val_accuracy: 0.8084 - val_loss: 0.6555
# Epoch 97/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 67s 95ms/step - accuracy: 0.9124 - loss: 0.2447 - val_accuracy: 0.8088 - val_loss: 0.6574
# Epoch 98/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.9125 - loss: 0.2404 - val_accuracy: 0.7994 - val_loss: 0.7057
# Epoch 99/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 64s 91ms/step - accuracy: 0.9120 - loss: 0.2384 - val_accuracy: 0.8074 - val_loss: 0.6662
# Epoch 100/100
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 66s 94ms/step - accuracy: 0.9134 - loss: 0.2390 - val_accuracy: 0.8084 - val_loss: 0.6822
# Test accuracy: 0.7900999784469604

# %%
import ANNarchy
from ANNarchy.extensions.ann_to_snn_conversion import ANNtoSNNConverter
ANNarchy.clear()
snn_converter = ANNtoSNNConverter(
    input_encoding='IB', 
    hidden_neuron='IaF',
    read_out='spike_count',
)
# Out:
# ANNarchy 4.8 (4.8.2.5) on linux (posix).

# %%
net = snn_converter.load_keras_model("CIFAR_v12_vgg.keras", show_info=True)
# Out:
# 2025-11-13 09:35:43.484466: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING: Dense representation is an experimental feature for spiking models, we greatly appreciate bug reports.
# * Input layer: input_layer, (32, 32, 3)
# * InputLayer skipped.
# * Conv2D layer: block1_conv1, (32, 32, 32)
# * Conv2D layer: block1_conv2, (32, 32, 32)
# * MaxPooling2D layer: block1_pool, (16, 16, 32)
# * Dropout skipped.
# * Conv2D layer: block2_conv1, (16, 16, 64)
# * Conv2D layer: block2_conv2, (16, 16, 64)
# * MaxPooling2D layer: block2_pool, (8, 8, 64)
# * Dropout skipped.
# * Conv2D layer: block3_conv1, (8, 8, 128)
# * Conv2D layer: block3_conv2, (8, 8, 128)
# * MaxPooling2D layer: block3_pool, (4, 4, 128)
# * Dropout skipped.
# * Flatten skipped.
# * Dense layer: fc1, 128
#     weights: (128, 2048)
#     mean -0.0014715614961460233, std 0.0350368395447731
#     min -0.1527700126171112, max 0.1419132500886917
# * Dropout skipped.
# * Dense layer: predictions, 10
#     weights: (10, 128)
#     mean 0.0006717192009091377, std 0.19445988535881042
#     min -0.45998871326446533, max 0.43983420729637146

# %%
predictions_snn = snn_converter.predict(test_data[:300], duration_per_sample=200)
# Out:
# 100%|██████████| 300/300 [33:30<00:00,  6.70s/it]

# %%
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

print(classification_report(test_labels[:300], predictions_snn))
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.61      0.68        36
#            1       0.88      0.92      0.90        24
#            2       0.61      0.74      0.67        27
#            3       0.44      0.62      0.51        29
#            4       0.87      0.57      0.68        23
#            5       0.54      0.68      0.60        28
#            6       1.00      0.59      0.74        34
#            7       0.79      0.70      0.75        27
#            8       0.73      0.86      0.79        37
#            9       0.85      0.83      0.84        35
#
#     accuracy                           0.71       300
#    macro avg       0.75      0.71      0.72       300
# weighted avg       0.75      0.71      0.72       300
#
# Test accuracy of the SNN: 0.7133333333333334

# %%
model = tf.keras.models.load_model('CIFAR_v12_vgg.keras')
loss, accuracy = model.evaluate(test_data, test_labels_onehot, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7901 - loss: 0.7469

# %%
print(f"Test accuracy of the ANN: {accuracy:.4f}")
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
# Test accuracy of the ANN: 0.7901
# Test accuracy of the SNN: 0.7133333333333334
