# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.layers import Activation
from keras.layers import Conv2D, MaxPooling2D, Input
from keras.layers import BatchNormalization
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Model
# Out:
# 2025-11-12 14:02:00.548694: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-12 14:02:00.558768: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 14:02:02.335359: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-12 14:02:06.589144: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 14:02:06.593458: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Download data
(train_data, train_labels), (test_data, test_labels) = cifar10.load_data()

# Normalize inputs
train_data = train_data.astype('float32') / 255.
test_data = test_data.astype('float32') / 255.

# One-hot output vectors
train_labels_onehot = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, 10)

# %%
_input = Input((32,32,3)) 

conv1  = Conv2D(filters=64, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(_input)
conv2  = Conv2D(filters=64, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv1)
pool1  = MaxPooling2D((2, 2))(conv2)

conv3  = Conv2D(filters=128, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(pool1)
conv4  = Conv2D(filters=128, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv3)
pool2  = MaxPooling2D((2, 2))(conv4)

conv5  = Conv2D(filters=256, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(pool2)
conv6  = Conv2D(filters=256, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv5)
conv7  = Conv2D(filters=256, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv6)
pool3  = MaxPooling2D((2, 2))(conv7)

conv8  = Conv2D(filters=512, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(pool3)
conv9  = Conv2D(filters=512, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv8)
conv10 = Conv2D(filters=512, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv9)
pool4  = MaxPooling2D((2, 2))(conv10)

conv11 = Conv2D(filters=512, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(pool4)
conv12 = Conv2D(filters=512, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv11)
conv13 = Conv2D(filters=512, use_bias=False, kernel_size=(3,3), padding="same", activation="relu")(conv12)
pool5  = MaxPooling2D((2, 2))(conv13)

flat   = Flatten()(pool5)
dense1 = Dense(512, use_bias=False, activation="relu")(flat)
dense2 = Dense(512, use_bias=False, activation="relu")(dense1)
output = Dense(10, use_bias=False, activation="softmax")(dense2)

vgg16_model  = Model(inputs=_input, outputs=output)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001)

# Loss function
vgg16_model.compile(
    loss='categorical_crossentropy', # loss function
    optimizer=optimizer, # learning rule
    metrics=['accuracy'] # show accuracy
    )
print(vgg16_model.summary())
# Out:
# 2025-11-12 14:02:17.002061: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 64)     │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 128)    │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 256)      │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 256)      │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 8, 8, 256)      │       589,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 512)      │     1,179,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 4, 4, 512)      │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 4, 4, 512)      │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 2, 2, 512)      │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 2, 2, 512)      │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 2, 2, 512)      │     2,359,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 1, 1, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         5,120 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,239,872 (58.14 MB)
#  Trainable params: 15,239,872 (58.14 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Train model (use one-hot labels)
history = vgg16_model.fit(
    train_data, train_labels_onehot,       # training data (one-hot labels)
    batch_size=128,                        # batch size
    epochs=20,                            # Maximum number of epochs
    validation_split=0.1,                  # Percentage of training data used for validation
)

# Test model: get class predictions and evaluate with one-hot labels
predictions_keras = np.argmax(vgg16_model.predict(test_data, verbose=0), axis=1)
test_loss, test_accuracy = vgg16_model.evaluate(test_data, test_labels_onehot, verbose=0)
print(f"Test accuracy: {test_accuracy}")
vgg16_model.save("CIFAR_v10_vgg.keras")
# Out:
# Epoch 1/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 428s 1s/step - accuracy: 0.1188 - loss: 2.3019 - val_accuracy: 0.0982 - val_loss: 2.3018
# Epoch 2/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 416s 1s/step - accuracy: 0.1238 - loss: 2.3013 - val_accuracy: 0.1432 - val_loss: 2.3009
# Epoch 3/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 417s 1s/step - accuracy: 0.1554 - loss: 2.3000 - val_accuracy: 0.1680 - val_loss: 2.2989
# Epoch 4/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.1747 - loss: 2.2960 - val_accuracy: 0.1732 - val_loss: 2.2915
# Epoch 5/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 407s 1s/step - accuracy: 0.1723 - loss: 2.2774 - val_accuracy: 0.1710 - val_loss: 2.2477
# Epoch 6/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 404s 1s/step - accuracy: 0.1827 - loss: 2.1804 - val_accuracy: 0.1726 - val_loss: 2.1992
# Epoch 7/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 406s 1s/step - accuracy: 0.2100 - loss: 2.1022 - val_accuracy: 0.2060 - val_loss: 2.1010
# Epoch 8/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 399s 1s/step - accuracy: 0.2322 - loss: 2.0416 - val_accuracy: 0.2112 - val_loss: 2.1216
# Epoch 9/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 391s 1s/step - accuracy: 0.2525 - loss: 1.9995 - val_accuracy: 0.2458 - val_loss: 2.0328
# Epoch 10/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 402s 1s/step - accuracy: 0.2753 - loss: 1.9531 - val_accuracy: 0.2862 - val_loss: 1.9236
# Epoch 11/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 406s 1s/step - accuracy: 0.2923 - loss: 1.9088 - val_accuracy: 0.2936 - val_loss: 1.8728
# Epoch 12/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 394s 1s/step - accuracy: 0.3000 - loss: 1.8723 - val_accuracy: 0.3150 - val_loss: 1.8209
# Epoch 13/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 397s 1s/step - accuracy: 0.3165 - loss: 1.8308 - val_accuracy: 0.3062 - val_loss: 1.8101
# Epoch 14/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 426s 1s/step - accuracy: 0.3343 - loss: 1.7865 - val_accuracy: 0.3384 - val_loss: 1.7403
# Epoch 15/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 401s 1s/step - accuracy: 0.3517 - loss: 1.7452 - val_accuracy: 0.2716 - val_loss: 2.0695
# Epoch 16/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.3724 - loss: 1.6952 - val_accuracy: 0.3470 - val_loss: 1.7711
# Epoch 17/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 404s 1s/step - accuracy: 0.3880 - loss: 1.6497 - val_accuracy: 0.3906 - val_loss: 1.6268
# Epoch 18/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 400s 1s/step - accuracy: 0.4029 - loss: 1.6128 - val_accuracy: 0.4030 - val_loss: 1.5813
# Epoch 19/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 415s 1s/step - accuracy: 0.4140 - loss: 1.5813 - val_accuracy: 0.4112 - val_loss: 1.5800
# Epoch 20/20
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 439s 1s/step - accuracy: 0.4264 - loss: 1.5431 - val_accuracy: 0.3302 - val_loss: 1.9150
# Test accuracy: 0.3345000147819519

# %%
import ANNarchy
from ANNarchy.extensions.ann_to_snn_conversion import ANNtoSNNConverter
ANNarchy.clear()
snn_converter = ANNtoSNNConverter(
    input_encoding='IB', 
    hidden_neuron='IaF',
    read_out='spike_count',
)
# Out:
# ANNarchy 4.8 (4.8.2.5) on linux (posix).

# %%
net = snn_converter.load_keras_model("CIFAR_v10_vgg.keras", show_info=True)
# Out:
# WARNING: Dense representation is an experimental feature for spiking models, we greatly appreciate bug reports.
# * Input layer: input_layer_3, (32, 32, 3)
# * InputLayer skipped.
# * Conv2D layer: conv2d_39, (32, 32, 64)
# * Conv2D layer: conv2d_40, (32, 32, 64)
# * MaxPooling2D layer: max_pooling2d_15, (16, 16, 64)
# * Conv2D layer: conv2d_41, (16, 16, 128)
# * Conv2D layer: conv2d_42, (16, 16, 128)
# * MaxPooling2D layer: max_pooling2d_16, (8, 8, 128)
# * Conv2D layer: conv2d_43, (8, 8, 256)
# * Conv2D layer: conv2d_44, (8, 8, 256)
# * Conv2D layer: conv2d_45, (8, 8, 256)
# * MaxPooling2D layer: max_pooling2d_17, (4, 4, 256)
# * Conv2D layer: conv2d_46, (4, 4, 512)
# * Conv2D layer: conv2d_47, (4, 4, 512)
# * Conv2D layer: conv2d_48, (4, 4, 512)
# * MaxPooling2D layer: max_pooling2d_18, (2, 2, 512)
# * Conv2D layer: conv2d_49, (2, 2, 512)
# * Conv2D layer: conv2d_50, (2, 2, 512)
# * Conv2D layer: conv2d_51, (2, 2, 512)
# * MaxPooling2D layer: max_pooling2d_19, (1, 1, 512)
# * Flatten skipped.
# * Dense layer: dense_9, 512
#     weights: (512, 512)
#     mean 0.0002269424730911851, std 0.04437030851840973
#     min -0.08219563215970993, max 0.08428042382001877
# * Dense layer: dense_10, 512
#     weights: (512, 512)
#     mean 0.00033875604276545346, std 0.04426806792616844
#     min -0.0829431414604187, max 0.09042030572891235
# * Dense layer: dense_11, 10
#     weights: (10, 512)
#     mean 8.625837654108182e-05, std 0.06667269766330719
#     min -0.15696778893470764, max 0.1674671769142151

# %%
predictions_snn = snn_converter.predict(test_data[:300], duration_per_sample=200)
# Out:
#   0%|          | 1/300 [00:55<4:38:31, 55.89s/it]

# %%
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

print(classification_report(test_labels[:300], predictions_snn))
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76        36
#            1       0.83      0.79      0.81        24
#            2       0.82      0.33      0.47        27
#            3       0.44      0.52      0.48        29
#            4       0.65      0.57      0.60        23
#            5       0.52      0.54      0.53        28
#            6       0.62      0.85      0.72        34
#            7       0.77      0.63      0.69        27
#            8       0.81      0.78      0.79        37
#            9       0.79      0.86      0.82        35
#
#     accuracy                           0.68       300
#    macro avg       0.70      0.67      0.67       300
# weighted avg       0.70      0.68      0.68       300
#
# Test accuracy of the SNN: 0.6833333333333333

# %%
model = tf.keras.models.load_model('CIFAR_v7.keras')
loss, accuracy = model.evaluate(test_data, test_labels_onehot, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.7160 - loss: 0.8520

# %%
print(f"Test accuracy of the ANN: {accuracy:.4f}")
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
# Test accuracy of the ANN: 0.7160
# Test accuracy of the SNN: 0.6833333333333333
