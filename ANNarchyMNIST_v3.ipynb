# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from keras.datasets import mnist


print(f"Tensorflow {tf.__version__}")
# Out:
# Tensorflow 2.20.0

# %%
def cnn_with_dropout():

    inputs = Input(shape = (28, 28, 1))
    x = Conv2D(16, kernel_size=(5,5),activation='relu',padding = 'same',use_bias=False)(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)
    x = Conv2D(64,kernel_size=(5,5),activation='relu',padding = 'same',use_bias=False)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)
    x = Conv2D(64,kernel_size=(5,5),activation='relu',padding = 'same',use_bias=False)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)
    x = Flatten()(x)
    x = Dense(10,activation='softmax',use_bias=False)(x)


    # Create functional model
    model= Model(inputs, x)
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

    # Loss function
    model.compile(
        loss='categorical_crossentropy', # loss function
        optimizer=optimizer, # learning rule
        metrics=['accuracy'] # show accuracy
    )
    print(model.summary())

    return model

# %%
# Download data
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# Normalize inputs
train_data = train_data.astype('float32') / 255.
test_data = test_data.astype('float32') / 255.

# One-hot output vectors
train_labels_onehot = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, 10)

# %%
model = cnn_with_dropout()

# Train model (use one-hot labels)
history = model.fit(
    train_data, train_labels_onehot,       # training data (one-hot labels)
    batch_size=128,                        # batch size
    epochs=20,                              # Maximum number of epochs
    validation_split=0.1,                  # Percentage of training data used for validation
)

# Test model: get class predictions and evaluate with one-hot labels
predictions_keras = np.argmax(model.predict(test_data, verbose=0), axis=1)
test_loss, test_accuracy = model.evaluate(test_data, test_labels_onehot, verbose=0)
print(f"Test accuracy: {test_accuracy}")
model.save("MNIST_v3.keras")
# Out:
# 2025-11-03 18:33:26.038901: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 16)     │           400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        25,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 64)       │       102,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         5,760 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 134,160 (524.06 KB)
#  Trainable params: 134,160 (524.06 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - accuracy: 0.3582 - loss: 1.8583 - val_accuracy: 0.8382 - val_loss: 0.7108
# Epoch 2/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 18s 42ms/step - accuracy: 0.7754 - loss: 0.7025 - val_accuracy: 0.9372 - val_loss: 0.2674
# Epoch 3/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.8700 - loss: 0.4176 - val_accuracy: 0.9568 - val_loss: 0.1722
# Epoch 4/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.9040 - loss: 0.3124 - val_accuracy: 0.9635 - val_loss: 0.1369
# Epoch 5/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 17s 41ms/step - accuracy: 0.9202 - loss: 0.2586 - val_accuracy: 0.9692 - val_loss: 0.1176
# Epoch 6/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - accuracy: 0.9298 - loss: 0.2302 - val_accuracy: 0.9705 - val_loss: 0.1042
# Epoch 7/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 18s 44ms/step - accuracy: 0.9366 - loss: 0.2054 - val_accuracy: 0.9737 - val_loss: 0.0938
# Epoch 8/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 19s 44ms/step - accuracy: 0.9436 - loss: 0.1857 - val_accuracy: 0.9758 - val_loss: 0.0857
# Epoch 9/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9467 - loss: 0.1708 - val_accuracy: 0.9765 - val_loss: 0.0814
# Epoch 10/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 24s 56ms/step - accuracy: 0.9503 - loss: 0.1616 - val_accuracy: 0.9788 - val_loss: 0.0764
# Epoch 11/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 0.9524 - loss: 0.1508 - val_accuracy: 0.9792 - val_loss: 0.0727
# Epoch 12/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 23s 56ms/step - accuracy: 0.9547 - loss: 0.1439 - val_accuracy: 0.9807 - val_loss: 0.0692
# Epoch 13/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 24s 57ms/step - accuracy: 0.9572 - loss: 0.1357 - val_accuracy: 0.9810 - val_loss: 0.0661
# Epoch 14/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9592 - loss: 0.1298 - val_accuracy: 0.9820 - val_loss: 0.0649
# Epoch 15/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - accuracy: 0.9602 - loss: 0.1265 - val_accuracy: 0.9820 - val_loss: 0.0615
# Epoch 16/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - accuracy: 0.9626 - loss: 0.1212 - val_accuracy: 0.9832 - val_loss: 0.0600
# Epoch 17/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9630 - loss: 0.1176 - val_accuracy: 0.9837 - val_loss: 0.0586
# Epoch 18/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 26s 61ms/step - accuracy: 0.9640 - loss: 0.1147 - val_accuracy: 0.9835 - val_loss: 0.0572
# Epoch 19/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 24s 57ms/step - accuracy: 0.9659 - loss: 0.1108 - val_accuracy: 0.9835 - val_loss: 0.0557
# Epoch 20/20
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 24s 56ms/step - accuracy: 0.9670 - loss: 0.1063 - val_accuracy: 0.9848 - val_loss: 0.0535
# Test accuracy: 0.9839000105857849

# %%
import ANNarchy
from ANNarchy.extensions.ann_to_snn_conversion import ANNtoSNNConverter
ANNarchy.clear()
snn_converter = ANNtoSNNConverter(
    input_encoding='IB', 
    hidden_neuron='IaF',
    read_out='spike_count',
)
# Out:
# ANNarchy 4.8 (4.8.2.5) on linux (posix).

# %%
net = snn_converter.load_keras_model("MNIST_v3.keras", show_info=True)
# Out:
# WARNING: Dense representation is an experimental feature for spiking models, we greatly appreciate bug reports.
# * Input layer: input_layer, (28, 28, 1)
# * InputLayer skipped.
# * Conv2D layer: conv2d, (28, 28, 16)
# * MaxPooling2D layer: max_pooling2d, (14, 14, 16)
# * Dropout skipped.
# * Conv2D layer: conv2d_1, (14, 14, 64)
# * MaxPooling2D layer: max_pooling2d_1, (7, 7, 64)
# * Dropout skipped.
# * Conv2D layer: conv2d_2, (7, 7, 64)
# * MaxPooling2D layer: max_pooling2d_2, (3, 3, 64)
# * Dropout skipped.
# * Flatten skipped.
# * Dense layer: dense, 10
#     weights: (10, 576)
#     mean 0.0003490092931315303, std 0.06957537680864334
#     min -0.24435296654701233, max 0.21154996752738953

# %%
predictions_snn = snn_converter.predict(test_data[:300], duration_per_sample=200)
# Out:
# 100%|██████████| 300/300 [08:46<00:00,  1.75s/it]

# %%
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

print(classification_report(test_labels[:300], predictions_snn))
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        24
#            4       1.00      0.97      0.99        37
#            5       1.00      1.00      1.00        29
#            6       0.96      0.96      0.96        24
#            7       1.00      1.00      1.00        34
#            8       0.91      1.00      0.95        21
#            9       1.00      0.94      0.97        34
#
#     accuracy                           0.99       300
#    macro avg       0.98      0.99      0.98       300
# weighted avg       0.99      0.99      0.99       300
#
# Test accuracy of the SNN: 0.9866666666666667

# %%
model = tf.keras.models.load_model('CIFAR_v2.keras')
loss, accuracy = model.evaluate(test_data, test_labels_onehot, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9915 - loss: 0.0272

# %%
print(f"Test accuracy of the ANN: {accuracy:.4f}")
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
# Test accuracy of the ANN: 0.9915
# Test accuracy of the SNN: 0.9866666666666667
