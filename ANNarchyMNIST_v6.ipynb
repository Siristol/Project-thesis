# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from keras.datasets import mnist


print(f"Tensorflow {tf.__version__}")
# Out:
# Tensorflow 2.20.0

# %%
def cnn_three_blocks_ecpos_100():

    inputs = tf.keras.Input(shape=(28, 28, 1))

    # Block 1
    x = Conv2D(32, (3, 3), padding='same', activation='relu', use_bias=False)(inputs)
    x = Conv2D(32, (3, 3), padding='same', activation='relu', use_bias=False)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)

    # Block 2
    x = Conv2D(64, (3, 3), padding='same', activation='relu', use_bias=False)(x)
    x = Conv2D(64, (3, 3), padding='same', activation='relu', use_bias=False)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.25)(x)

    # Block 3
    x = Conv2D(128, (3, 3), padding='same', activation='relu', use_bias=False)(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.4)(x)

    # Classifier
    x = Flatten()(x)
    x = Dense(256, use_bias=False)(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(10, activation='softmax', use_bias=False)(x)


    # Create functional model
    model= Model(inputs, outputs)
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)

    # Loss function
    model.compile(
        loss='categorical_crossentropy', # loss function
        optimizer=optimizer, # learning rule
        metrics=['accuracy'] # show accuracy
    )
    print(model.summary())

    return model

# %%
# Download data
(train_data, train_labels), (test_data, test_labels) = mnist.load_data()

# Normalize inputs
train_data = train_data.astype('float32') / 255.
test_data = test_data.astype('float32') / 255.

# One-hot output vectors
train_labels_onehot = tf.keras.utils.to_categorical(train_labels, 10)
test_labels_onehot = tf.keras.utils.to_categorical(test_labels, 10)

# %%
model = cnn_three_blocks_ecpos_100()

# Train model (use one-hot labels)
history = model.fit(
    train_data, train_labels_onehot,       # training data (one-hot labels)
    batch_size=128,                        # batch size
    epochs=100,                            # Maximum number of epochs
    validation_split=0.1,                  # Percentage of training data used for validation
)

# Test model: get class predictions and evaluate with one-hot labels
predictions_keras = np.argmax(model.predict(test_data, verbose=0), axis=1)
test_loss, test_accuracy = model.evaluate(test_data, test_labels_onehot, verbose=0)
print(f"Test accuracy: {test_accuracy}")
model.save("CIFAR_v2.keras")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 32)     │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 28, 28, 32)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 14, 14, 64)     │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 14, 14, 64)     │        36,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 7, 7, 128)      │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,560 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 436,000 (1.66 MB)
#  Trainable params: 436,000 (1.66 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 172ms/step - accuracy: 0.1359 - loss: 2.2778 - val_accuracy: 0.6472 - val_loss: 2.1524
# Epoch 2/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 178ms/step - accuracy: 0.4872 - loss: 1.4853 - val_accuracy: 0.9122 - val_loss: 0.3976
# Epoch 3/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 185ms/step - accuracy: 0.8133 - loss: 0.5765 - val_accuracy: 0.9563 - val_loss: 0.1671
# Epoch 4/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 86s 204ms/step - accuracy: 0.8827 - loss: 0.3747 - val_accuracy: 0.9640 - val_loss: 0.1257
# Epoch 5/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 186ms/step - accuracy: 0.9050 - loss: 0.3059 - val_accuracy: 0.9650 - val_loss: 0.1159
# Epoch 6/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 185ms/step - accuracy: 0.9213 - loss: 0.2578 - val_accuracy: 0.9732 - val_loss: 0.0916
# Epoch 7/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9287 - loss: 0.2313 - val_accuracy: 0.9742 - val_loss: 0.0823
# Epoch 8/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 76s 180ms/step - accuracy: 0.9348 - loss: 0.2096 - val_accuracy: 0.9757 - val_loss: 0.0781
# Epoch 9/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 173ms/step - accuracy: 0.9399 - loss: 0.1950 - val_accuracy: 0.9772 - val_loss: 0.0724
# Epoch 10/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 176ms/step - accuracy: 0.9437 - loss: 0.1811 - val_accuracy: 0.9783 - val_loss: 0.0674
# Epoch 11/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 87s 188ms/step - accuracy: 0.9488 - loss: 0.1676 - val_accuracy: 0.9798 - val_loss: 0.0633
# Epoch 12/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 84s 199ms/step - accuracy: 0.9509 - loss: 0.1589 - val_accuracy: 0.9815 - val_loss: 0.0593
# Epoch 13/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 178ms/step - accuracy: 0.9550 - loss: 0.1455 - val_accuracy: 0.9802 - val_loss: 0.0648
# Epoch 14/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 182ms/step - accuracy: 0.9564 - loss: 0.1440 - val_accuracy: 0.9832 - val_loss: 0.0545
# Epoch 15/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 85s 201ms/step - accuracy: 0.9576 - loss: 0.1396 - val_accuracy: 0.9840 - val_loss: 0.0538
# Epoch 16/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 93s 219ms/step - accuracy: 0.9601 - loss: 0.1307 - val_accuracy: 0.9843 - val_loss: 0.0512
# Epoch 17/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 76s 181ms/step - accuracy: 0.9608 - loss: 0.1276 - val_accuracy: 0.9842 - val_loss: 0.0493
# Epoch 18/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 76s 181ms/step - accuracy: 0.9619 - loss: 0.1230 - val_accuracy: 0.9843 - val_loss: 0.0470
# Epoch 19/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9644 - loss: 0.1192 - val_accuracy: 0.9858 - val_loss: 0.0460
# Epoch 20/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 173ms/step - accuracy: 0.9660 - loss: 0.1106 - val_accuracy: 0.9857 - val_loss: 0.0437
# Epoch 21/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 76s 181ms/step - accuracy: 0.9660 - loss: 0.1109 - val_accuracy: 0.9868 - val_loss: 0.0417
# Epoch 22/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 72s 170ms/step - accuracy: 0.9671 - loss: 0.1092 - val_accuracy: 0.9870 - val_loss: 0.0427
# Epoch 23/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 189ms/step - accuracy: 0.9668 - loss: 0.1065 - val_accuracy: 0.9882 - val_loss: 0.0416
# Epoch 24/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 187ms/step - accuracy: 0.9692 - loss: 0.1007 - val_accuracy: 0.9877 - val_loss: 0.0408
# Epoch 25/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 175ms/step - accuracy: 0.9705 - loss: 0.0975 - val_accuracy: 0.9887 - val_loss: 0.0394
# Epoch 26/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 173ms/step - accuracy: 0.9706 - loss: 0.0952 - val_accuracy: 0.9883 - val_loss: 0.0392
# Epoch 27/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9709 - loss: 0.0924 - val_accuracy: 0.9880 - val_loss: 0.0374
# Epoch 28/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 190ms/step - accuracy: 0.9722 - loss: 0.0930 - val_accuracy: 0.9895 - val_loss: 0.0378
# Epoch 29/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 76s 181ms/step - accuracy: 0.9720 - loss: 0.0898 - val_accuracy: 0.9892 - val_loss: 0.0370
# Epoch 30/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 185ms/step - accuracy: 0.9728 - loss: 0.0885 - val_accuracy: 0.9898 - val_loss: 0.0358
# Epoch 31/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 178ms/step - accuracy: 0.9745 - loss: 0.0839 - val_accuracy: 0.9893 - val_loss: 0.0350
# Epoch 32/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9741 - loss: 0.0846 - val_accuracy: 0.9892 - val_loss: 0.0353
# Epoch 33/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 175ms/step - accuracy: 0.9737 - loss: 0.0839 - val_accuracy: 0.9902 - val_loss: 0.0348
# Epoch 34/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 174ms/step - accuracy: 0.9756 - loss: 0.0804 - val_accuracy: 0.9893 - val_loss: 0.0351
# Epoch 35/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 188ms/step - accuracy: 0.9744 - loss: 0.0817 - val_accuracy: 0.9897 - val_loss: 0.0339
# Epoch 36/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 87s 206ms/step - accuracy: 0.9764 - loss: 0.0763 - val_accuracy: 0.9897 - val_loss: 0.0334
# Epoch 37/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 181ms/step - accuracy: 0.9767 - loss: 0.0761 - val_accuracy: 0.9907 - val_loss: 0.0338
# Epoch 38/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 84s 186ms/step - accuracy: 0.9767 - loss: 0.0749 - val_accuracy: 0.9907 - val_loss: 0.0332
# Epoch 39/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 89s 211ms/step - accuracy: 0.9757 - loss: 0.0756 - val_accuracy: 0.9910 - val_loss: 0.0319
# Epoch 40/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 187ms/step - accuracy: 0.9773 - loss: 0.0715 - val_accuracy: 0.9907 - val_loss: 0.0320
# Epoch 41/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 178ms/step - accuracy: 0.9780 - loss: 0.0714 - val_accuracy: 0.9912 - val_loss: 0.0316
# Epoch 42/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 185ms/step - accuracy: 0.9778 - loss: 0.0712 - val_accuracy: 0.9912 - val_loss: 0.0314
# Epoch 43/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 189ms/step - accuracy: 0.9784 - loss: 0.0705 - val_accuracy: 0.9900 - val_loss: 0.0314
# Epoch 44/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 186ms/step - accuracy: 0.9795 - loss: 0.0683 - val_accuracy: 0.9902 - val_loss: 0.0320
# Epoch 45/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 189ms/step - accuracy: 0.9795 - loss: 0.0678 - val_accuracy: 0.9905 - val_loss: 0.0298
# Epoch 46/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 84s 199ms/step - accuracy: 0.9786 - loss: 0.0680 - val_accuracy: 0.9913 - val_loss: 0.0302
# Epoch 47/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 183ms/step - accuracy: 0.9796 - loss: 0.0653 - val_accuracy: 0.9915 - val_loss: 0.0299
# Epoch 48/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 176ms/step - accuracy: 0.9804 - loss: 0.0636 - val_accuracy: 0.9912 - val_loss: 0.0299
# Epoch 49/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 176ms/step - accuracy: 0.9803 - loss: 0.0622 - val_accuracy: 0.9907 - val_loss: 0.0296
# Epoch 50/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 172ms/step - accuracy: 0.9804 - loss: 0.0631 - val_accuracy: 0.9913 - val_loss: 0.0300
# Epoch 51/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 84s 176ms/step - accuracy: 0.9807 - loss: 0.0633 - val_accuracy: 0.9910 - val_loss: 0.0296
# Epoch 52/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 187ms/step - accuracy: 0.9811 - loss: 0.0609 - val_accuracy: 0.9908 - val_loss: 0.0291
# Epoch 53/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 72s 171ms/step - accuracy: 0.9821 - loss: 0.0587 - val_accuracy: 0.9915 - val_loss: 0.0288
# Epoch 54/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 83s 174ms/step - accuracy: 0.9816 - loss: 0.0589 - val_accuracy: 0.9915 - val_loss: 0.0280
# Epoch 55/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9817 - loss: 0.0593 - val_accuracy: 0.9918 - val_loss: 0.0274
# Epoch 56/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 81s 192ms/step - accuracy: 0.9814 - loss: 0.0595 - val_accuracy: 0.9917 - val_loss: 0.0277
# Epoch 57/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 72s 170ms/step - accuracy: 0.9824 - loss: 0.0566 - val_accuracy: 0.9925 - val_loss: 0.0277
# Epoch 58/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 70s 166ms/step - accuracy: 0.9827 - loss: 0.0560 - val_accuracy: 0.9920 - val_loss: 0.0274
# Epoch 59/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 70s 165ms/step - accuracy: 0.9827 - loss: 0.0571 - val_accuracy: 0.9922 - val_loss: 0.0271
# Epoch 60/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 189ms/step - accuracy: 0.9827 - loss: 0.0552 - val_accuracy: 0.9923 - val_loss: 0.0271
# Epoch 61/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 190ms/step - accuracy: 0.9826 - loss: 0.0553 - val_accuracy: 0.9920 - val_loss: 0.0260
# Epoch 62/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 181ms/step - accuracy: 0.9825 - loss: 0.0557 - val_accuracy: 0.9925 - val_loss: 0.0273
# Epoch 63/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 84s 198ms/step - accuracy: 0.9826 - loss: 0.0558 - val_accuracy: 0.9915 - val_loss: 0.0286
# Epoch 64/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 176ms/step - accuracy: 0.9821 - loss: 0.0563 - val_accuracy: 0.9917 - val_loss: 0.0269
# Epoch 65/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 185ms/step - accuracy: 0.9839 - loss: 0.0515 - val_accuracy: 0.9918 - val_loss: 0.0263
# Epoch 66/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 181ms/step - accuracy: 0.9843 - loss: 0.0511 - val_accuracy: 0.9918 - val_loss: 0.0267
# Epoch 67/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 174ms/step - accuracy: 0.9843 - loss: 0.0527 - val_accuracy: 0.9923 - val_loss: 0.0256
# Epoch 68/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 179ms/step - accuracy: 0.9842 - loss: 0.0511 - val_accuracy: 0.9918 - val_loss: 0.0264
# Epoch 69/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 184ms/step - accuracy: 0.9838 - loss: 0.0516 - val_accuracy: 0.9922 - val_loss: 0.0266
# Epoch 70/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 87s 195ms/step - accuracy: 0.9830 - loss: 0.0526 - val_accuracy: 0.9920 - val_loss: 0.0255
# Epoch 71/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 183ms/step - accuracy: 0.9849 - loss: 0.0487 - val_accuracy: 0.9923 - val_loss: 0.0259
# Epoch 72/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 175ms/step - accuracy: 0.9841 - loss: 0.0508 - val_accuracy: 0.9920 - val_loss: 0.0266
# Epoch 73/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 184ms/step - accuracy: 0.9844 - loss: 0.0495 - val_accuracy: 0.9927 - val_loss: 0.0260
# Epoch 74/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 188ms/step - accuracy: 0.9850 - loss: 0.0486 - val_accuracy: 0.9922 - val_loss: 0.0250
# Epoch 75/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 180ms/step - accuracy: 0.9848 - loss: 0.0482 - val_accuracy: 0.9925 - val_loss: 0.0250
# Epoch 76/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 85s 202ms/step - accuracy: 0.9859 - loss: 0.0467 - val_accuracy: 0.9923 - val_loss: 0.0247
# Epoch 77/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 79s 186ms/step - accuracy: 0.9851 - loss: 0.0481 - val_accuracy: 0.9927 - val_loss: 0.0249
# Epoch 78/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 175ms/step - accuracy: 0.9855 - loss: 0.0474 - val_accuracy: 0.9923 - val_loss: 0.0253
# Epoch 79/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 71s 168ms/step - accuracy: 0.9858 - loss: 0.0451 - val_accuracy: 0.9920 - val_loss: 0.0245
# Epoch 80/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 70s 166ms/step - accuracy: 0.9858 - loss: 0.0483 - val_accuracy: 0.9928 - val_loss: 0.0246
# Epoch 81/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 70s 165ms/step - accuracy: 0.9855 - loss: 0.0459 - val_accuracy: 0.9927 - val_loss: 0.0247
# Epoch 82/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 81s 192ms/step - accuracy: 0.9859 - loss: 0.0463 - val_accuracy: 0.9922 - val_loss: 0.0244
# Epoch 83/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 172ms/step - accuracy: 0.9866 - loss: 0.0439 - val_accuracy: 0.9927 - val_loss: 0.0242
# Epoch 84/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 71s 167ms/step - accuracy: 0.9859 - loss: 0.0448 - val_accuracy: 0.9930 - val_loss: 0.0247
# Epoch 85/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 93s 221ms/step - accuracy: 0.9865 - loss: 0.0442 - val_accuracy: 0.9923 - val_loss: 0.0248
# Epoch 86/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 86s 203ms/step - accuracy: 0.9858 - loss: 0.0464 - val_accuracy: 0.9930 - val_loss: 0.0240
# Epoch 87/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 78s 185ms/step - accuracy: 0.9863 - loss: 0.0436 - val_accuracy: 0.9922 - val_loss: 0.0248
# Epoch 88/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 172ms/step - accuracy: 0.9863 - loss: 0.0426 - val_accuracy: 0.9920 - val_loss: 0.0253
# Epoch 89/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 182ms/step - accuracy: 0.9867 - loss: 0.0416 - val_accuracy: 0.9927 - val_loss: 0.0245
# Epoch 90/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 177ms/step - accuracy: 0.9860 - loss: 0.0437 - val_accuracy: 0.9923 - val_loss: 0.0244
# Epoch 91/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 73s 172ms/step - accuracy: 0.9873 - loss: 0.0411 - val_accuracy: 0.9927 - val_loss: 0.0240
# Epoch 92/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 72s 171ms/step - accuracy: 0.9875 - loss: 0.0410 - val_accuracy: 0.9932 - val_loss: 0.0242
# Epoch 93/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 174ms/step - accuracy: 0.9869 - loss: 0.0411 - val_accuracy: 0.9922 - val_loss: 0.0241
# Epoch 94/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9864 - loss: 0.0420 - val_accuracy: 0.9932 - val_loss: 0.0236
# Epoch 95/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 183ms/step - accuracy: 0.9876 - loss: 0.0408 - val_accuracy: 0.9925 - val_loss: 0.0237
# Epoch 96/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 176ms/step - accuracy: 0.9873 - loss: 0.0403 - val_accuracy: 0.9922 - val_loss: 0.0236
# Epoch 97/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 74s 175ms/step - accuracy: 0.9872 - loss: 0.0409 - val_accuracy: 0.9923 - val_loss: 0.0240
# Epoch 98/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 77s 181ms/step - accuracy: 0.9875 - loss: 0.0401 - val_accuracy: 0.9928 - val_loss: 0.0231
# Epoch 99/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 75s 177ms/step - accuracy: 0.9883 - loss: 0.0386 - val_accuracy: 0.9927 - val_loss: 0.0249
# Epoch 100/100
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 76s 180ms/step - accuracy: 0.9878 - loss: 0.0391 - val_accuracy: 0.9925 - val_loss: 0.0242
# Test accuracy: 0.9937000274658203

# %%
import ANNarchy
from ANNarchy.extensions.ann_to_snn_conversion import ANNtoSNNConverter
ANNarchy.clear()
snn_converter = ANNtoSNNConverter(
    input_encoding='IB', 
    hidden_neuron='IaF',
    read_out='spike_count',
)
# Out:
# ANNarchy 4.8 (4.8.2.5) on linux (posix).

# %%
net = snn_converter.load_keras_model("CIFAR_v2.keras", show_info=True)
# Out:
# 2025-11-06 11:17:41.924804: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-06 11:17:41.927148: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-06 11:17:42.201313: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-06 11:17:44.204886: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-06 11:17:44.208256: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-06 11:17:45.344388: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# WARNING: Dense representation is an experimental feature for spiking models, we greatly appreciate bug reports.
# * Input layer: input_layer_1, (28, 28, 1)
# * InputLayer skipped.
# * Conv2D layer: conv2d_5, (28, 28, 32)
# * Conv2D layer: conv2d_6, (28, 28, 32)
# * MaxPooling2D layer: max_pooling2d_3, (14, 14, 32)
# * Dropout skipped.
# * Conv2D layer: conv2d_7, (14, 14, 64)
# * Conv2D layer: conv2d_8, (14, 14, 64)
# * MaxPooling2D layer: max_pooling2d_4, (7, 7, 64)
# * Dropout skipped.
# * Conv2D layer: conv2d_9, (7, 7, 128)
# * MaxPooling2D layer: max_pooling2d_5, (3, 3, 128)
# * Dropout skipped.
# * Flatten skipped.
# * Dense layer: dense_2, 256
#     weights: (256, 1152)
#     mean -0.0006090263486839831, std 0.03802994266152382
#     min -0.11883995682001114, max 0.1181797906756401
# * Activation skipped.
# * Dropout skipped.
# * Dense layer: dense_3, 10
#     weights: (10, 256)
#     mean -0.0012305330019444227, std 0.10003773868083954
#     min -0.25657472014427185, max 0.20399850606918335

# %%
predictions_snn = snn_converter.predict(test_data[:300], duration_per_sample=200)
# Out:
# 100%|██████████| 300/300 [20:19<00:00,  4.07s/it]

# %%
from sklearn.metrics import classification_report, accuracy_score
import numpy as np

print(classification_report(test_labels[:300], predictions_snn))
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       1.00      1.00      1.00        41
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        24
#            4       1.00      0.95      0.97        37
#            5       1.00      1.00      1.00        29
#            6       0.96      0.96      0.96        24
#            7       1.00      1.00      1.00        34
#            8       1.00      1.00      1.00        21
#            9       0.97      1.00      0.99        34
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300
#
# Test accuracy of the SNN: 0.99

# %%
model = tf.keras.models.load_model('CIFAR_v2.keras')
loss, accuracy = model.evaluate(test_data, test_labels_onehot, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9937 - loss: 0.0186

# %%
print(f"Test accuracy of the ANN: {accuracy:.4f}")
print("Test accuracy of the SNN:", accuracy_score(test_labels[:300], predictions_snn))
# Out:
# Test accuracy of the ANN: 0.9937
# Test accuracy of the SNN: 0.99
